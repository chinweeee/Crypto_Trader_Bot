# %% [markdown]
# <a href="https://colab.research.google.com/github/chinweeee/Crypto_Trader_Bot/blob/main/ML_Trader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api_key = "x_your_api_key"
secret_key = "4f_your_secret_key"

# %%
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
import pandas as pd

# %% [markdown]
# Aunthenticate

# %%
client = Client(api_key, secret_key)

# %% [markdown]
# Get Tickers for every single Crypto-currency pair

# %%
tickers = client.get_all_tickers()
tickers
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.05326000'},
#  {'symbol': 'LTCBTC', 'price': '0.00189900'},
#  {'symbol': 'BNBBTC', 'price': '0.00667300'},
#  {'symbol': 'NEOBTC', 'price': '0.00029760'},
#  {'symbol': 'QTUMETH', 'price': '0.00156700'},
#  {'symbol': 'EOSETH', 'price': '0.00036020'},
#  {'symbol': 'SNTETH', 'price': '0.00002126'},
#  {'symbol': 'BNTETH', 'price': '0.00038610'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00022160'},
#  {'symbol': 'BNBETH', 'price': '0.12530000'},
#  {'symbol': 'BTCUSDT', 'price': '36018.51000000'},
#  {'symbol': 'ETHUSDT', 'price': '1918.37000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00000443'},
# ...

# %%
#accessing the symbols and price
for ticker in tickers:
    symbol = ticker['symbol']
    price = ticker['price']
    print('Symbol:', symbol, 'Price:', price)
# Out:
# Symbol: ETHBTC Price: 0.05326000
# Symbol: LTCBTC Price: 0.00189900
# Symbol: BNBBTC Price: 0.00667300
# Symbol: NEOBTC Price: 0.00029760
# Symbol: QTUMETH Price: 0.00156700
# Symbol: EOSETH Price: 0.00036020
# Symbol: SNTETH Price: 0.00002126
# Symbol: BNTETH Price: 0.00038610
# Symbol: BCCBTC Price: 0.07908100
# Symbol: GASBTC Price: 0.00022160
# Symbol: BNBETH Price: 0.12530000
# Symbol: BTCUSDT Price: 36018.51000000
# Symbol: ETHUSDT Price: 1918.37000000
# Symbol: HSRBTC Price: 0.00041400
# Symbol: OAXETH Price: 0.00017780
# Symbol: DNTETH Price: 0.00002801
# Symbol: MCOETH Price: 0.00577200
# Symbol: ICNETH Price: 0.00166300
# Symbol: MCOBTC Price: 0.00021140
# Symbol: WTCBTC Price: 0.00000443
# Symbol: WTCETH Price: 0.00023700
# Symbol: LRCBTC Price: 0.00000608
# Symbol: LRCETH Price: 0.00011370
# Symbol: QTUMBTC Price: 0.00008350
# Symbol: YOYOBTC Price: 0.00000008
# Symbol: OMGBTC Price: 0.00003080
# Symbol: OMGETH Price: 0.00079100
# Symbol: ZRXBTC Price: 0.00001170
# ...

# %%
tickers_val = client.get_all_tickers()
tickers_val
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.05323000'},
#  {'symbol': 'LTCBTC', 'price': '0.00189800'},
#  {'symbol': 'BNBBTC', 'price': '0.00668000'},
#  {'symbol': 'NEOBTC', 'price': '0.00029760'},
#  {'symbol': 'QTUMETH', 'price': '0.00156700'},
#  {'symbol': 'EOSETH', 'price': '0.00036050'},
#  {'symbol': 'SNTETH', 'price': '0.00002126'},
#  {'symbol': 'BNTETH', 'price': '0.00038810'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00022240'},
#  {'symbol': 'BNBETH', 'price': '0.12540000'},
#  {'symbol': 'BTCUSDT', 'price': '35980.02000000'},
#  {'symbol': 'ETHUSDT', 'price': '1915.65000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00000441'},
# ...

# %%
tickers_val_df = pd.DataFrame(tickers_val)
tickers_val_df.head()
# Out:
#     symbol       price
# 0   ETHBTC  0.05323000
# 1   LTCBTC  0.00189800
# 2   BNBBTC  0.00668000
# 3   NEOBTC  0.00029760
# 4  QTUMETH  0.00156700

# %%
#Set the symbol as the index
tickers_val_df.set_index('symbol', inplace=True)
tickers_val_df
# Out:
#                 price
# symbol
# ETHBTC     0.05323000
# LTCBTC     0.00189800
# BNBBTC     0.00668000
# NEOBTC     0.00029760
# QTUMETH    0.00156700
# ...               ...
# CAKETUSD   2.40400000
# DYDXFDUSD  3.34100000
# PIVXUSDT   0.46650000
# RUNEFDUSD  5.91000000
# TIATUSD    6.10900000
#
# [2358 rows x 1 columns]

# %%
#To Grab a Price for Specific Currency Pair
tickers_val_df.loc['BTCUSDT']
# Out:
# price    35980.02000000
# Name: BTCUSDT, dtype: object

# %%
float(tickers_val_df.loc['ETHBTC']['price'])
# Out:
# 0.05323

# %% [markdown]
# Get Depth

# %%
#Market Depth for Ethereum Bitcoin pair
depth = client.get_order_book(symbol='ETHBTC')
depth
# Out:
# {'lastUpdateId': 6919079727,
#  'bids': [['0.05327000', '33.42660000'],
#   ['0.05326000', '20.97910000'],
#   ['0.05325000', '15.29580000'],
#   ['0.05324000', '8.31940000'],
#   ['0.05323000', '8.00850000'],
#   ['0.05322000', '61.62210000'],
#   ['0.05321000', '9.74250000'],
#   ['0.05320000', '58.08640000'],
#   ['0.05319000', '9.09970000'],
#   ['0.05318000', '26.16370000'],
#   ['0.05317000', '0.25000000'],
#   ['0.05316000', '72.13360000'],
#   ['0.05315000', '141.08390000'],
#   ['0.05314000', '0.41070000'],
#   ['0.05313000', '62.51410000'],
#   ['0.05312000', '15.64740000'],
#   ['0.05311000', '2.29660000'],
#   ['0.05310000', '152.19790000'],
#   ['0.05309000', '122.13520000'],
#   ['0.05308000', '0.32920000'],
#   ['0.05307000', '0.31360000'],
#   ['0.05306000', '0.28600000'],
#   ['0.05305000', '0.43410000'],
#   ['0.05304000', '1.42440000'],
#   ['0.05303000', '0.41520000'],
#   ['0.05302000', '2.02500000'],
#   ['0.05301000', '122.10020000'],
# ...

# %%
#viz the asks
depth_df = pd.DataFrame(depth['asks'])
depth_df.columns = ['Price', 'Volume']
depth_df.head()
# Out:
#         Price       Volume
# 0  0.05328000  23.03980000
# 1  0.05329000  27.55950000
# 2  0.05330000   7.09800000
# 3  0.05331000  16.43610000
# 4  0.05332000  15.37010000

# %%
depth_df.dtypes
# Out:
# Price     object
# Volume    object
# dtype: object

# %% [markdown]
# Get Historical Data

# %%
#Convert to Numbers
historical = client.get_historical_klines('ETHBTC', Client.KLINE_INTERVAL_1DAY, '1 Jan 2011')
historical
# Out:
# [[1499990400000,
#   '0.08000000',
#   '0.09103300',
#   '0.08000000',
#   '0.09099300',
#   '1942.05700000',
#   1500076799999,
#   '170.23852396',
#   1994,
#   '1076.40500000',
#   '94.82527222',
#   '0'],
#  [1500076800000,
#   '0.09099300',
#   '0.09369900',
#   '0.08712700',
#   '0.08763500',
#   '4013.06600000',
#   1500163199999,
#   '363.03178785',
#   4623,
#   '2250.31800000',
#   '203.54149755',
#   '0'],
#  [1500163200000,
#   '0.08750800',
#   '0.08763500',
#   '0.07559100',
#   '0.08224100',
#   '8904.15800000',
#   1500249599999,
#   '722.21248196',
#   8137,
#   '5557.57500000',
#   '450.34388688',
#   '0'],
#  [1500249600000,
#   '0.08236800',
#   '0.08839400',
#   '0.08169900',
#   '0.08753700',
#   '6650.93300000',
#   1500335999999,
#   '568.24653804',
#   7639,
#   '3859.48500000',
#   '329.66875309',
#   '0'],
#  [1500336000000,
#   '0.08783100',
#   '0.10906800',
#   '0.08477700',
#   '0.10773200',
#   '7245.74100000',
#   1500422399999,
#   '674.49785037',
# ...

# %%
hist_df = pd.DataFrame(historical)
hist_df.head()
# Out:
#               0           1           2           3           4   \
# 0  1499990400000  0.08000000  0.09103300  0.08000000  0.09099300
# 1  1500076800000  0.09099300  0.09369900  0.08712700  0.08763500
# 2  1500163200000  0.08750800  0.08763500  0.07559100  0.08224100
# 3  1500249600000  0.08236800  0.08839400  0.08169900  0.08753700
# 4  1500336000000  0.08783100  0.10906800  0.08477700  0.10773200
#
#               5              6             7     8              9   \
# 0  1942.05700000  1500076799999  170.23852396  1994  1076.40500000
# 1  4013.06600000  1500163199999  363.03178785  4623  2250.31800000
# 2  8904.15800000  1500249599999  722.21248196  8137  5557.57500000
# 3  6650.93300000  1500335999999  568.24653804  7639  3859.48500000
# 4  7245.74100000  1500422399999  674.49785037  8121  4202.05500000
#
#              10 11
# 0   94.82527222  0
# 1  203.54149755  0
# 2  450.34388688  0
# 3  329.66875309  0
# 4  393.11140275  0

# %%
#Change column names
hist_df.columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time', 'Quote Asset Volume'
                  , 'Number of Trades', 'TB Base Volume', 'TB Quote Volume', 'Ignore']

hist_df.tail()
# Out:
#       Open Time        Open        High         Low       Close  \
# 2313 2023-11-13  0.05516000  0.05735000  0.05508000  0.05631000
# 2314 2023-11-14  0.05631000  0.05653000  0.05542000  0.05568000
# 2315 2023-11-15  0.05568000  0.05603000  0.05420000  0.05438000
# 2316 2023-11-16  0.05437000  0.05578000  0.05410000  0.05424000
# 2317 2023-11-17  0.05424000  0.05460000  0.05300000  0.05302000
#
#               Volume                    Close Time Quote Asset Volume  \
# 2313  59168.27680000 2023-11-13 23:59:59.999000064      3327.14478115
# 2314  40039.47710000 2023-11-14 23:59:59.999000064      2244.09660795
# 2315  37528.09610000 2023-11-15 23:59:59.999000064      2068.52340515
# 2316  47351.90490000 2023-11-16 23:59:59.999000064      2600.80671889
# 2317  25963.45690000 2023-11-17 23:59:59.999000064      1397.16382809
#
#       Number of Trades  TB Base Volume TB Quote Volume Ignore
# 2313             91858  28568.82140000   1606.07849283      0
# ...

# %%
hist_df.shape
# Out:
# (2318, 12)

# %% [markdown]
# Preprocess Historical Data

# %%
#Now change the datatypes
hist_df.dtypes
# Out:
# Open Time             datetime64[ns]
# Open                          object
# High                          object
# Low                           object
# Close                         object
# Volume                        object
# Close Time            datetime64[ns]
# Quote Asset Volume            object
# Number of Trades               int64
# TB Base Volume                object
# TB Quote Volume               object
# Ignore                        object
# dtype: object

# %%
#Convert these to date time
# hist_df['Open Time'] = pd.to_datetime(hist_df['Open Time']/1000, unit='s')
# hist_df['Close Time'] = pd.to_datetime(hist_df['Close Time']/1000, unit='s')
# hist_df.tail()

# %%
hist_df.dtypes
# Out:
# Open Time             datetime64[ns]
# Open                          object
# High                          object
# Low                           object
# Close                         object
# Volume                        object
# Close Time            datetime64[ns]
# Quote Asset Volume            object
# Number of Trades               int64
# TB Base Volume                object
# TB Quote Volume               object
# Ignore                        object
# dtype: object

# %%
#Convert to numbers

# to_be_num = ['Open', 'High', 'Low', 'Close', 'Volume', 'Quote Asset Volume', 'TB Base Volume', 'TB Quote Volume']
# hist_df[to_be_num] = hist_df[to_be_num].apply(pd.to_numeric, axis=1)
hist_df.tail()
hist_df.dtypes
# Out:
# Open Time             datetime64[ns]
# Open                         float64
# High                         float64
# Low                          float64
# Close                        float64
# Volume                       float64
# Close Time            datetime64[ns]
# Quote Asset Volume           float64
# Number of Trades               int64
# TB Base Volume               float64
# TB Quote Volume              float64
# Ignore                        object
# dtype: object

# %%
hist_df.tail()
# Out:
#       Open Time     Open     High      Low    Close      Volume  \
# 2313 2023-11-13  0.05516  0.05735  0.05508  0.05631  59168.2768
# 2314 2023-11-14  0.05631  0.05653  0.05542  0.05568  40039.4771
# 2315 2023-11-15  0.05568  0.05603  0.05420  0.05438  37528.0961
# 2316 2023-11-16  0.05437  0.05578  0.05410  0.05424  47351.9049
# 2317 2023-11-17  0.05424  0.05460  0.05300  0.05302  25963.4569
#
#                         Close Time  Quote Asset Volume  Number of Trades  \
# 2313 2023-11-13 23:59:59.999000064         3327.144781             91858
# 2314 2023-11-14 23:59:59.999000064         2244.096608             70986
# 2315 2023-11-15 23:59:59.999000064         2068.523405             70413
# 2316 2023-11-16 23:59:59.999000064         2600.806719             74113
# 2317 2023-11-17 23:59:59.999000064         1397.163828             38650
#
#       TB Base Volume  TB Quote Volume Ignore
# 2313      28568.8214      1606.078493      0
# 2314      19570.5086      1097.005018      0
# ...

# %%
hist_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2318.000000  2318.000000  2318.000000  2318.000000  2.318000e+03
# mean      0.051442     0.052486     0.050348     0.051429  1.664357e+05
# std       0.021701     0.022137     0.021254     0.021692  1.377410e+05
# min       0.016415     0.016560     0.016150     0.016415  1.942057e+03
# 25%       0.031086     0.031672     0.030448     0.031086  7.665231e+04
# 50%       0.057187     0.058317     0.055758     0.057140  1.305654e+05
# 75%       0.070176     0.071346     0.068850     0.070111  2.219404e+05
# max       0.113075     0.123799     0.109343     0.113185  1.396957e+06
#
#        Quote Asset Volume  Number of Trades  TB Base Volume  TB Quote Volume
# count         2318.000000      2.318000e+03     2318.000000      2318.000000
# mean          7199.043880      1.837831e+05    83311.440176      3596.163026
# std           5657.637783      1.304582e+05    68870.518839      2789.076327
# ...

# %%
hist_df.describe(include='object')
# Out:
#        Ignore
# count    2318
# unique      1
# top         0
# freq     2318

# %%
hist_df.describe(include='datetime64[ns]')
# Out:
# /var/folders/29/z_qcrfh91n30mjn_998lcrcm0000gp/T/ipykernel_84720/2996143359.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   hist_df.describe(include='datetime64[ns]')
# /var/folders/29/z_qcrfh91n30mjn_998lcrcm0000gp/T/ipykernel_84720/2996143359.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   hist_df.describe(include='datetime64[ns]')
#                   Open Time                     Close Time
# count                  2318                           2318
# unique                 2318                           2318
# top     2017-07-14 00:00:00  2017-07-14 23:59:59.999000064
# ...

# %%
hist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2318 entries, 0 to 2317
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Open Time           2318 non-null   datetime64[ns]
#  1   Open                2318 non-null   float64
#  2   High                2318 non-null   float64
#  3   Low                 2318 non-null   float64
#  4   Close               2318 non-null   float64
#  5   Volume              2318 non-null   float64
#  6   Close Time          2318 non-null   datetime64[ns]
#  7   Quote Asset Volume  2318 non-null   float64
#  8   Number of Trades    2318 non-null   int64
#  9   TB Base Volume      2318 non-null   float64
#  10  TB Quote Volume     2318 non-null   float64
#  11  Ignore              2318 non-null   object
# dtypes: datetime64[ns](2), float64(8), int64(1), object(1)
# memory usage: 217.4+ KB

# %% [markdown]
# Vizualization

# %%
import mplfinance as mpf

# %%
#Historical Data of ETHBTC
mpf.plot(hist_df.set_index('Close Time').tail(100))

# %%
mpf.plot(hist_df.set_index('Close Time'))
# Out:
# /Users/chinwe/opt/anaconda3/lib/python3.9/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(hist_df.set_index('Close Time').tail(100)
        , type = 'candle', style='charles'
        , volume = True
        , title = 'ETHBTC Trading Trend (Past 100 Days)'
        , mav = (15,30))
